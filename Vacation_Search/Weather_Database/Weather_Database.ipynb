# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 742

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
city_weather.json()
# Out:
# {'coord': {'lon': -71.0598, 'lat': 42.3584},
#  'weather': [{'id': 804,
#    'main': 'Clouds',
#    'description': 'overcast clouds',
#    'icon': '04n'}],
#  'base': 'stations',
#  'main': {'temp': 36.43,
#   'feels_like': 33.78,
#   'temp_min': 33.64,
#   'temp_max': 37.51,
#   'pressure': 1011,
#   'humidity': 52},
#  'visibility': 10000,
#  'wind': {'speed': 3.44, 'deg': 220},
#  'clouds': {'all': 90},
#  'dt': 1638147056,
#  'sys': {'type': 1,
#   'id': 3486,
#   'country': 'US',
#   'sunrise': 1638100259,
#   'sunset': 1638134042},
#  'timezone': -18000,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | victoria
# Processing Record 2 of Set 1 | tuktoyaktuk
# Processing Record 3 of Set 1 | ushuaia
# Processing Record 4 of Set 1 | lourdes
# Processing Record 5 of Set 1 | lebu
# Processing Record 6 of Set 1 | airai
# Processing Record 7 of Set 1 | vaini
# Processing Record 8 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 9 of Set 1 | nova vicosa
# Processing Record 10 of Set 1 | saint-philippe
# Processing Record 11 of Set 1 | dabhol
# Processing Record 12 of Set 1 | henties bay
# Processing Record 13 of Set 1 | fortuna foothills
# Processing Record 14 of Set 1 | busselton
# Processing Record 15 of Set 1 | talnakh
# Processing Record 16 of Set 1 | atuona
# Processing Record 17 of Set 1 | necochea
# Processing Record 18 of Set 1 | hilo
# Processing Record 19 of Set 1 | yellowknife
# Processing Record 20 of Set 1 | lagoa
# Processing Record 21 of Set 1 | wanlaweyn
# Processing Record 22 of Set 1 | cidreira
# Processing Record 23 of Set 1 | belturbet
# Processing Record 24 of Set 1 | rikitea
# Processing Record 25 of Set 1 | ishigaki
# Processing Record 26 of Set 1 | yar-sale
# Processing Record 27 of Set 1 | punta arenas
# Processing Record 28 of Set 1 | hermanus
# Processing Record 29 of Set 1 | olafsvik
# Processing Record 30 of Set 1 | husavik
# Processing Record 31 of Set 1 | aksu
# Processing Record 32 of Set 1 | dhidhdhoo
# Processing Record 33 of Set 1 | avarua
# Processing Record 34 of Set 1 | iqaluit
# Processing Record 35 of Set 1 | asau
# Processing Record 36 of Set 1 | visnes
# Processing Record 37 of Set 1 | bathsheba
# Processing Record 38 of Set 1 | bonavista
# Processing Record 39 of Set 1 | souillac
# Processing Record 40 of Set 1 | tiksi
# Processing Record 41 of Set 1 | port alfred
# Processing Record 42 of Set 1 | kaabong
# Processing Record 43 of Set 1 | albany
# Processing Record 44 of Set 1 | puerto ayora
# Processing Record 45 of Set 1 | cap malheureux
# Processing Record 46 of Set 1 | east london
# Processing Record 47 of Set 1 | half moon bay
# Processing Record 48 of Set 1 | edson
# Processing Record 49 of Set 1 | carauari
# Processing Record 50 of Set 1 | mahebourg
# Processing Record 1 of Set 2 | severo-kurilsk
# Processing Record 2 of Set 2 | victor harbor
# Processing Record 3 of Set 2 | tupik
# Processing Record 4 of Set 2 | kapaa
# Processing Record 5 of Set 2 | buala
# Processing Record 6 of Set 2 | semirom
# Processing Record 7 of Set 2 | iskateley
# Processing Record 8 of Set 2 | khonuu
# City not found. Skipping...
# Processing Record 9 of Set 2 | mataura
# Processing Record 10 of Set 2 | karad
# Processing Record 11 of Set 2 | san cristobal
# Processing Record 12 of Set 2 | alofi
# Processing Record 13 of Set 2 | ribeira grande
# Processing Record 14 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 15 of Set 2 | ruma
# Processing Record 16 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 17 of Set 2 | santa maria del oro
# Processing Record 18 of Set 2 | beloha
# Processing Record 19 of Set 2 | pasighat
# Processing Record 20 of Set 2 | the valley
# Processing Record 21 of Set 2 | marzuq
# Processing Record 22 of Set 2 | yaring
# Processing Record 23 of Set 2 | agirish
# Processing Record 24 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 25 of Set 2 | alugan
# Processing Record 26 of Set 2 | inhambane
# Processing Record 27 of Set 2 | bocaranga
# City not found. Skipping...
# Processing Record 28 of Set 2 | hobart
# Processing Record 29 of Set 2 | nuuk
# Processing Record 30 of Set 2 | hervey bay
# Processing Record 31 of Set 2 | georgetown
# Processing Record 32 of Set 2 | road town
# Processing Record 33 of Set 2 | hualmay
# Processing Record 34 of Set 2 | avera
# Processing Record 35 of Set 2 | plettenberg bay
# Processing Record 36 of Set 2 | nikolskoye
# Processing Record 37 of Set 2 | pangnirtung
# Processing Record 38 of Set 2 | jamestown
# Processing Record 39 of Set 2 | amvrosiyivka
# Processing Record 40 of Set 2 | rocha
# Processing Record 41 of Set 2 | bethel
# Processing Record 42 of Set 2 | bluff
# Processing Record 43 of Set 2 | qaanaaq
# Processing Record 44 of Set 2 | paamiut
# Processing Record 45 of Set 2 | lasa
# Processing Record 46 of Set 2 | butaritari
# Processing Record 47 of Set 2 | guerrero negro
# Processing Record 48 of Set 2 | cape town
# Processing Record 49 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 50 of Set 2 | verkhoyansk
# Processing Record 1 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 2 of Set 3 | mehamn
# Processing Record 3 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 4 of Set 3 | nalut
# Processing Record 5 of Set 3 | faanui
# Processing Record 6 of Set 3 | ilebo
# Processing Record 7 of Set 3 | yenotayevka
# Processing Record 8 of Set 3 | shelburne
# Processing Record 9 of Set 3 | luderitz
# Processing Record 10 of Set 3 | mayo
# Processing Record 11 of Set 3 | vestmannaeyjar
# Processing Record 12 of Set 3 | flinders
# Processing Record 13 of Set 3 | longyearbyen
# Processing Record 14 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 15 of Set 3 | provideniya
# Processing Record 16 of Set 3 | deputatskiy
# Processing Record 17 of Set 3 | odweyne
# Processing Record 18 of Set 3 | rio grande
# Processing Record 19 of Set 3 | westport
# Processing Record 20 of Set 3 | port blair
# Processing Record 21 of Set 3 | bucerias
# Processing Record 22 of Set 3 | thompson
# Processing Record 23 of Set 3 | bagacay
# Processing Record 24 of Set 3 | bambous virieux
# Processing Record 25 of Set 3 | mabay
# Processing Record 26 of Set 3 | lavrentiya
# Processing Record 27 of Set 3 | fairbanks
# Processing Record 28 of Set 3 | pontianak
# Processing Record 29 of Set 3 | narsaq
# Processing Record 30 of Set 3 | vao
# Processing Record 31 of Set 3 | arraial do cabo
# Processing Record 32 of Set 3 | bagdarin
# Processing Record 33 of Set 3 | praia da vitoria
# Processing Record 34 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 35 of Set 3 | los llanos de aridane
# Processing Record 36 of Set 3 | gat
# Processing Record 37 of Set 3 | coihaique
# Processing Record 38 of Set 3 | saskylakh
# Processing Record 39 of Set 3 | kodiak
# Processing Record 40 of Set 3 | neiafu
# Processing Record 41 of Set 3 | cherskiy
# Processing Record 42 of Set 3 | chuy
# Processing Record 43 of Set 3 | hobyo
# Processing Record 44 of Set 3 | carutapera
# Processing Record 45 of Set 3 | carnarvon
# Processing Record 46 of Set 3 | padang
# Processing Record 47 of Set 3 | kaitangata
# Processing Record 48 of Set 3 | umm lajj
# Processing Record 49 of Set 3 | terrace
# Processing Record 50 of Set 3 | porto belo
# Processing Record 1 of Set 4 | ayolas
# Processing Record 2 of Set 4 | pontes e lacerda
# Processing Record 3 of Set 4 | lorengau
# Processing Record 4 of Set 4 | guozhen
# Processing Record 5 of Set 4 | nabire
# Processing Record 6 of Set 4 | kavaratti
# Processing Record 7 of Set 4 | sento se
# City not found. Skipping...
# Processing Record 8 of Set 4 | nyrob
# Processing Record 9 of Set 4 | mar del plata
# Processing Record 10 of Set 4 | clarence town
# Processing Record 11 of Set 4 | colares
# Processing Record 12 of Set 4 | meybod
# Processing Record 13 of Set 4 | chumikan
# Processing Record 14 of Set 4 | coquimbo
# Processing Record 15 of Set 4 | zhuhai
# Processing Record 16 of Set 4 | pangody
# Processing Record 17 of Set 4 | acapulco
# Processing Record 18 of Set 4 | vostok
# Processing Record 19 of Set 4 | alihe
# Processing Record 20 of Set 4 | alberton
# Processing Record 21 of Set 4 | kieta
# Processing Record 22 of Set 4 | bud
# Processing Record 23 of Set 4 | castro
# Processing Record 24 of Set 4 | kathmandu
# Processing Record 25 of Set 4 | marsh harbour
# Processing Record 26 of Set 4 | kahului
# Processing Record 27 of Set 4 | tasiilaq
# Processing Record 28 of Set 4 | nantucket
# Processing Record 29 of Set 4 | gangotri
# City not found. Skipping...
# Processing Record 30 of Set 4 | tiznit
# Processing Record 31 of Set 4 | kamenskoye
# City not found. Skipping...
# Processing Record 32 of Set 4 | vilhena
# Processing Record 33 of Set 4 | takoradi
# Processing Record 34 of Set 4 | sabang
# Processing Record 35 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 36 of Set 4 | nome
# Processing Record 37 of Set 4 | raudeberg
# Processing Record 38 of Set 4 | baykit
# Processing Record 39 of Set 4 | ormos korthiou
# City not found. Skipping...
# Processing Record 40 of Set 4 | nanortalik
# Processing Record 41 of Set 4 | bilibino
# Processing Record 42 of Set 4 | kosonsoy
# Processing Record 43 of Set 4 | katwa
# Processing Record 44 of Set 4 | havre
# Processing Record 45 of Set 4 | dikson
# Processing Record 46 of Set 4 | port elizabeth
# Processing Record 47 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 48 of Set 4 | vila franca do campo
# Processing Record 49 of Set 4 | hasaki
# Processing Record 50 of Set 4 | warri
# Processing Record 1 of Set 5 | barrow
# Processing Record 2 of Set 5 | purranque
# Processing Record 3 of Set 5 | villanueva de cordoba
# Processing Record 4 of Set 5 | ornskoldsvik
# Processing Record 5 of Set 5 | san patricio
# Processing Record 6 of Set 5 | guanare
# Processing Record 7 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 8 of Set 5 | wisla
# Processing Record 9 of Set 5 | sovetskiy
# Processing Record 10 of Set 5 | ixtapa
# Processing Record 11 of Set 5 | tuy hoa
# Processing Record 12 of Set 5 | tura
# Processing Record 13 of Set 5 | goma
# Processing Record 14 of Set 5 | pisco
# Processing Record 15 of Set 5 | khor
# Processing Record 16 of Set 5 | kavieng
# Processing Record 17 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 18 of Set 5 | vacha
# Processing Record 19 of Set 5 | baglung
# Processing Record 20 of Set 5 | cabinda
# Processing Record 21 of Set 5 | port hedland
# Processing Record 22 of Set 5 | erechim
# Processing Record 23 of Set 5 | gambo
# Processing Record 24 of Set 5 | strezhevoy
# Processing Record 25 of Set 5 | lompoc
# Processing Record 26 of Set 5 | cascais
# Processing Record 27 of Set 5 | lata
# Processing Record 28 of Set 5 | dingle
# Processing Record 29 of Set 5 | prilep
# Processing Record 30 of Set 5 | sola
# Processing Record 31 of Set 5 | hithadhoo
# Processing Record 32 of Set 5 | wukari
# Processing Record 33 of Set 5 | sitka
# Processing Record 34 of Set 5 | benghazi
# Processing Record 35 of Set 5 | belogorsk
# Processing Record 36 of Set 5 | ponta do sol
# Processing Record 37 of Set 5 | hambantota
# Processing Record 38 of Set 5 | tabiauea
# City not found. Skipping...
# Processing Record 39 of Set 5 | gizo
# Processing Record 40 of Set 5 | udachnyy
# Processing Record 41 of Set 5 | burnie
# Processing Record 42 of Set 5 | chokurdakh
# Processing Record 43 of Set 5 | teterow
# Processing Record 44 of Set 5 | cabo san lucas
# Processing Record 45 of Set 5 | vila velha
# Processing Record 46 of Set 5 | hihifo
# City not found. Skipping...
# Processing Record 47 of Set 5 | alto araguaia
# Processing Record 48 of Set 5 | camocim
# Processing Record 49 of Set 5 | buin
# Processing Record 50 of Set 5 | alice springs
# Processing Record 1 of Set 6 | akureyri
# Processing Record 2 of Set 6 | bredasdorp
# Processing Record 3 of Set 6 | nelson bay
# Processing Record 4 of Set 6 | egvekinot
# Processing Record 5 of Set 6 | mbekenyera
# Processing Record 6 of Set 6 | lake city
# Processing Record 7 of Set 6 | miraflores
# Processing Record 8 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 9 of Set 6 | diffa
# Processing Record 10 of Set 6 | viligili
# City not found. Skipping...
# Processing Record 11 of Set 6 | igarka
# Processing Record 12 of Set 6 | torbay
# Processing Record 13 of Set 6 | burkhala
# City not found. Skipping...
# Processing Record 14 of Set 6 | juneau
# Processing Record 15 of Set 6 | maneadero
# Processing Record 16 of Set 6 | esil
# Processing Record 17 of Set 6 | aripuana
# Processing Record 18 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 19 of Set 6 | ilulissat
# Processing Record 20 of Set 6 | grootfontein
# Processing Record 21 of Set 6 | charagua
# Processing Record 22 of Set 6 | guasdualito
# Processing Record 23 of Set 6 | camacha
# Processing Record 24 of Set 6 | mount gambier
# Processing Record 25 of Set 6 | puerto del rosario
# Processing Record 26 of Set 6 | taltal
# Processing Record 27 of Set 6 | leeton
# Processing Record 28 of Set 6 | balikpapan
# Processing Record 29 of Set 6 | saint george
# Processing Record 30 of Set 6 | namibe
# Processing Record 31 of Set 6 | laguna
# Processing Record 32 of Set 6 | new norfolk
# Processing Record 33 of Set 6 | yanam
# Processing Record 34 of Set 6 | bolungarvik
# City not found. Skipping...
# Processing Record 35 of Set 6 | vadamadurai
# Processing Record 36 of Set 6 | batagay-alyta
# Processing Record 37 of Set 6 | birao
# Processing Record 38 of Set 6 | lazaro cardenas
# Processing Record 39 of Set 6 | codrington
# Processing Record 40 of Set 6 | pevek
# Processing Record 41 of Set 6 | fortuna
# Processing Record 42 of Set 6 | ahipara
# Processing Record 43 of Set 6 | chapais
# Processing Record 44 of Set 6 | cantanhede
# Processing Record 45 of Set 6 | susacon
# Processing Record 46 of Set 6 | bartow
# Processing Record 47 of Set 6 | phan rang
# City not found. Skipping...
# Processing Record 48 of Set 6 | aguimes
# Processing Record 49 of Set 6 | bowen
# Processing Record 50 of Set 6 | tabuk
# Processing Record 1 of Set 7 | parana
# Processing Record 2 of Set 7 | saldanha
# Processing Record 3 of Set 7 | genhe
# Processing Record 4 of Set 7 | darnah
# Processing Record 5 of Set 7 | cururupu
# Processing Record 6 of Set 7 | biak
# Processing Record 7 of Set 7 | rawson
# Processing Record 8 of Set 7 | vidosi
# Processing Record 9 of Set 7 | yerbogachen
# Processing Record 10 of Set 7 | saint-pierre
# Processing Record 11 of Set 7 | ullapool
# Processing Record 12 of Set 7 | veraval
# Processing Record 13 of Set 7 | ayacucho
# Processing Record 14 of Set 7 | portland
# Processing Record 15 of Set 7 | lock haven
# Processing Record 16 of Set 7 | sterling
# Processing Record 17 of Set 7 | thomaston
# Processing Record 18 of Set 7 | manokwari
# Processing Record 19 of Set 7 | carikar
# City not found. Skipping...
# Processing Record 20 of Set 7 | bakel
# Processing Record 21 of Set 7 | sulat
# Processing Record 22 of Set 7 | the pas
# Processing Record 23 of Set 7 | constitucion
# Processing Record 24 of Set 7 | nushki
# Processing Record 25 of Set 7 | marang
# Processing Record 26 of Set 7 | agadez
# Processing Record 27 of Set 7 | luwuk
# Processing Record 28 of Set 7 | geresk
# City not found. Skipping...
# Processing Record 29 of Set 7 | karaul
# City not found. Skipping...
# Processing Record 30 of Set 7 | dzhusaly
# City not found. Skipping...
# Processing Record 31 of Set 7 | upernavik
# Processing Record 32 of Set 7 | marawi
# Processing Record 33 of Set 7 | north bend
# Processing Record 34 of Set 7 | port hardy
# Processing Record 35 of Set 7 | severodvinsk
# Processing Record 36 of Set 7 | sobolevo
# Processing Record 37 of Set 7 | shiyan
# Processing Record 38 of Set 7 | bonthe
# Processing Record 39 of Set 7 | nobeoka
# Processing Record 40 of Set 7 | lodingen
# Processing Record 41 of Set 7 | ancud
# Processing Record 42 of Set 7 | hofn
# Processing Record 43 of Set 7 | belmonte
# Processing Record 44 of Set 7 | havoysund
# Processing Record 45 of Set 7 | priladozhskiy
# Processing Record 46 of Set 7 | jalu
# Processing Record 47 of Set 7 | patrocinio
# Processing Record 48 of Set 7 | eldoret
# Processing Record 49 of Set 7 | trelew
# Processing Record 50 of Set 7 | dodge city
# Processing Record 1 of Set 8 | nemuro
# Processing Record 2 of Set 8 | jequie
# Processing Record 3 of Set 8 | bac lieu
# Processing Record 4 of Set 8 | bardiyah
# Processing Record 5 of Set 8 | garowe
# Processing Record 6 of Set 8 | verkhniye kigi
# Processing Record 7 of Set 8 | prince rupert
# Processing Record 8 of Set 8 | innisfail
# Processing Record 9 of Set 8 | odienne
# Processing Record 10 of Set 8 | meulaboh
# Processing Record 11 of Set 8 | hokitika
# Processing Record 12 of Set 8 | tuatapere
# Processing Record 13 of Set 8 | santa cruz
# Processing Record 14 of Set 8 | wichita falls
# Processing Record 15 of Set 8 | kenai
# Processing Record 16 of Set 8 | okhotsk
# Processing Record 17 of Set 8 | tabou
# Processing Record 18 of Set 8 | aconibe
# Processing Record 19 of Set 8 | aykhal
# Processing Record 20 of Set 8 | toowoomba
# Processing Record 21 of Set 8 | ambilobe
# Processing Record 22 of Set 8 | alotau
# City not found. Skipping...
# Processing Record 23 of Set 8 | galiwinku
# City not found. Skipping...
# Processing Record 24 of Set 8 | sattahip
# Processing Record 25 of Set 8 | sioux lookout
# Processing Record 26 of Set 8 | mersin
# Processing Record 27 of Set 8 | khatanga
# Processing Record 28 of Set 8 | klaksvik
# Processing Record 29 of Set 8 | narayangarh
# Processing Record 30 of Set 8 | katsuura
# Processing Record 31 of Set 8 | puerto carreno
# Processing Record 32 of Set 8 | conde
# Processing Record 33 of Set 8 | bojnurd
# Processing Record 34 of Set 8 | sur
# Processing Record 35 of Set 8 | auki
# Processing Record 36 of Set 8 | arman
# Processing Record 37 of Set 8 | margate
# Processing Record 38 of Set 8 | boda
# Processing Record 39 of Set 8 | qasigiannguit
# Processing Record 40 of Set 8 | la rioja
# Processing Record 41 of Set 8 | sicamous
# Processing Record 42 of Set 8 | borovichi
# Processing Record 43 of Set 8 | kostino
# Processing Record 44 of Set 8 | la gaulette
# City not found. Skipping...
# Processing Record 45 of Set 8 | wiarton
# Processing Record 46 of Set 8 | talcahuano
# Processing Record 47 of Set 8 | concarneau
# Processing Record 48 of Set 8 | clyde river
# Processing Record 49 of Set 8 | korhogo
# Processing Record 50 of Set 8 | port keats
# Processing Record 1 of Set 9 | salalah
# Processing Record 2 of Set 9 | leningradskiy
# Processing Record 3 of Set 9 | edgewater
# Processing Record 4 of Set 9 | pforzheim
# Processing Record 5 of Set 9 | wewak
# Processing Record 6 of Set 9 | christchurch
# Processing Record 7 of Set 9 | anta
# Processing Record 8 of Set 9 | recreio
# Processing Record 9 of Set 9 | grindavik
# Processing Record 10 of Set 9 | warrington
# Processing Record 11 of Set 9 | dongsheng
# Processing Record 12 of Set 9 | knurow
# Processing Record 13 of Set 9 | lalmohan
# Processing Record 14 of Set 9 | glendive
# Processing Record 15 of Set 9 | cockburn harbour
# City not found. Skipping...
# Processing Record 16 of Set 9 | athabasca
# Processing Record 17 of Set 9 | mandalgovi
# Processing Record 18 of Set 9 | saint-georges
# Processing Record 19 of Set 9 | mitsamiouli
# Processing Record 20 of Set 9 | sturgis
# Processing Record 21 of Set 9 | verkhniy avzyan
# Processing Record 22 of Set 9 | tubmanburg
# Processing Record 23 of Set 9 | tarko-sale
# Processing Record 24 of Set 9 | yulara
# Processing Record 25 of Set 9 | hay river
# Processing Record 26 of Set 9 | kindia
# Processing Record 27 of Set 9 | awjilah
# Processing Record 28 of Set 9 | panzhihua
# Processing Record 29 of Set 9 | lukaya
# Processing Record 30 of Set 9 | shache
# Processing Record 31 of Set 9 | san andres
# Processing Record 32 of Set 9 | buchanan
# Processing Record 33 of Set 9 | lewiston
# Processing Record 34 of Set 9 | parainen
# Processing Record 35 of Set 9 | petropavlovsk-kamchatskiy
# Processing Record 36 of Set 9 | kruisfontein
# Processing Record 37 of Set 9 | ostrovnoy
# Processing Record 38 of Set 9 | punalur
# Processing Record 39 of Set 9 | berbera
# Processing Record 40 of Set 9 | deniliquin
# Processing Record 41 of Set 9 | jishou
# Processing Record 42 of Set 9 | kirakira
# Processing Record 43 of Set 9 | coolum beach
# Processing Record 44 of Set 9 | batticaloa
# Processing Record 45 of Set 9 | sungaipenuh
# Processing Record 46 of Set 9 | pitimbu
# Processing Record 47 of Set 9 | san jose
# Processing Record 48 of Set 9 | havelock
# Processing Record 49 of Set 9 | tuggurt
# City not found. Skipping...
# Processing Record 50 of Set 9 | ngukurr
# City not found. Skipping...
# Processing Record 1 of Set 10 | defiance
# Processing Record 2 of Set 10 | miranda
# Processing Record 3 of Set 10 | panna
# Processing Record 4 of Set 10 | labelle
# Processing Record 5 of Set 10 | shubarshi
# Processing Record 6 of Set 10 | te anau
# Processing Record 7 of Set 10 | nouadhibou
# Processing Record 8 of Set 10 | verkhnyaya inta
# Processing Record 9 of Set 10 | estelle
# Processing Record 10 of Set 10 | xinyang
# Processing Record 11 of Set 10 | port perry
# Processing Record 12 of Set 10 | lakhtar
# Processing Record 13 of Set 10 | denison
# Processing Record 14 of Set 10 | zamania
# Processing Record 15 of Set 10 | carepa
# Processing Record 16 of Set 10 | aktau
# Processing Record 17 of Set 10 | puerto lleras
# Processing Record 18 of Set 10 | gagino
# Processing Record 19 of Set 10 | valdivia
# Processing Record 20 of Set 10 | dwarka
# Processing Record 21 of Set 10 | ndele
# Processing Record 22 of Set 10 | karpathos
# Processing Record 23 of Set 10 | yirol
# City not found. Skipping...
# Processing Record 24 of Set 10 | isangel
# Processing Record 25 of Set 10 | zabolotovka
# Processing Record 26 of Set 10 | darhan
# Processing Record 27 of Set 10 | gazli
# Processing Record 28 of Set 10 | talen
# Processing Record 29 of Set 10 | cayenne
# Processing Record 30 of Set 10 | hamilton
# Processing Record 31 of Set 10 | kargopol
# Processing Record 32 of Set 10 | nishihara
# Processing Record 33 of Set 10 | xichang
# Processing Record 34 of Set 10 | zvishavane
# Processing Record 35 of Set 10 | naryan-mar
# Processing Record 36 of Set 10 | natal
# Processing Record 37 of Set 10 | acari
# Processing Record 38 of Set 10 | kholuy
# Processing Record 39 of Set 10 | skrunda
# Processing Record 40 of Set 10 | ahuimanu
# Processing Record 41 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 42 of Set 10 | hirara
# Processing Record 43 of Set 10 | karauzyak
# City not found. Skipping...
# Processing Record 44 of Set 10 | aklavik
# Processing Record 45 of Set 10 | abu jubayhah
# City not found. Skipping...
# Processing Record 46 of Set 10 | san blas
# Processing Record 47 of Set 10 | maniitsoq
# Processing Record 48 of Set 10 | vestmanna
# Processing Record 49 of Set 10 | wanning
# Processing Record 50 of Set 10 | maceio
# Processing Record 1 of Set 11 | faya
# Processing Record 2 of Set 11 | mineros
# Processing Record 3 of Set 11 | asfi
# Processing Record 4 of Set 11 | la ligua
# Processing Record 5 of Set 11 | dudinka
# Processing Record 6 of Set 11 | synya
# Processing Record 7 of Set 11 | erdenet
# Processing Record 8 of Set 11 | saint-leu
# Processing Record 9 of Set 11 | grand gaube
# Processing Record 10 of Set 11 | mezen
# Processing Record 11 of Set 11 | ambodifototra
# City not found. Skipping...
# Processing Record 12 of Set 11 | makiwalo
# Processing Record 13 of Set 11 | calhoun
# Processing Record 14 of Set 11 | naze
# Processing Record 15 of Set 11 | rong kwang
# Processing Record 16 of Set 11 | bosansko grahovo
# Processing Record 17 of Set 11 | san quintin
# Processing Record 18 of Set 11 | agadir
# Processing Record 19 of Set 11 | luwingu
# Processing Record 20 of Set 11 | chicama
# Processing Record 21 of Set 11 | karasjok
# Processing Record 22 of Set 11 | kotovo
# Processing Record 23 of Set 11 | nueva loja
# Processing Record 24 of Set 11 | tigil
# Processing Record 25 of Set 11 | champerico
# Processing Record 26 of Set 11 | chunoyar
# Processing Record 27 of Set 11 | oriximina
# Processing Record 28 of Set 11 | norman wells
# Processing Record 29 of Set 11 | turukhansk
# Processing Record 30 of Set 11 | flin flon
# Processing Record 31 of Set 11 | benjamin constant
# Processing Record 32 of Set 11 | ust-maya
# Processing Record 33 of Set 11 | bloemfontein
# Processing Record 34 of Set 11 | bolshoy tsaryn
# City not found. Skipping...
# Processing Record 35 of Set 11 | louisbourg
# City not found. Skipping...
# Processing Record 36 of Set 11 | halalo
# City not found. Skipping...
# Processing Record 37 of Set 11 | tromso
# Processing Record 38 of Set 11 | san policarpo
# Processing Record 39 of Set 11 | port lincoln
# Processing Record 40 of Set 11 | san francisco
# Processing Record 41 of Set 11 | ucluelet
# Processing Record 42 of Set 11 | smithers
# Processing Record 43 of Set 11 | vardo
# Processing Record 44 of Set 11 | bonanza
# Processing Record 45 of Set 11 | verkhneuralsk
# Processing Record 46 of Set 11 | talara
# Processing Record 47 of Set 11 | emba
# Processing Record 48 of Set 11 | moree
# Processing Record 49 of Set 11 | lahaina
# Processing Record 50 of Set 11 | mandeville
# Processing Record 1 of Set 12 | taoudenni
# Processing Record 2 of Set 12 | kailua
# Processing Record 3 of Set 12 | ankazobe
# Processing Record 4 of Set 12 | lixourion
# Processing Record 5 of Set 12 | ribeira brava
# Processing Record 6 of Set 12 | hessisch lichtenau
# Processing Record 7 of Set 12 | fort nelson
# Processing Record 8 of Set 12 | sug-aksy
# City not found. Skipping...
# Processing Record 9 of Set 12 | qaqortoq
# Processing Record 10 of Set 12 | sao jose da coroa grande
# Processing Record 11 of Set 12 | durango
# Processing Record 12 of Set 12 | skibbereen
# Processing Record 13 of Set 12 | olavarria
# Processing Record 14 of Set 12 | usinsk
# Processing Record 15 of Set 12 | uyuni
# Processing Record 16 of Set 12 | durres
# Processing Record 17 of Set 12 | saint-augustin
# Processing Record 18 of Set 12 | gresham
# Processing Record 19 of Set 12 | barabai
# Processing Record 20 of Set 12 | comodoro rivadavia
# Processing Record 21 of Set 12 | mayor pablo lagerenza
# Processing Record 22 of Set 12 | la ronge
# Processing Record 23 of Set 12 | savalou
# Processing Record 24 of Set 12 | ipilan
# Processing Record 25 of Set 12 | adrar
# Processing Record 26 of Set 12 | malwan
# City not found. Skipping...
# Processing Record 27 of Set 12 | okha
# Processing Record 28 of Set 12 | west bay
# Processing Record 29 of Set 12 | yaransk
# Processing Record 30 of Set 12 | galbshtadt
# Processing Record 31 of Set 12 | ambon
# Processing Record 32 of Set 12 | elbasan
# Processing Record 33 of Set 12 | plomarion
# Processing Record 34 of Set 12 | canavieiras
# Processing Record 35 of Set 12 | malanje
# Processing Record 36 of Set 12 | eureka
# Processing Record 37 of Set 12 | la orilla
# Processing Record 38 of Set 12 | bereda
# Processing Record 39 of Set 12 | lethem
# Processing Record 40 of Set 12 | sinkat
# City not found. Skipping...
# Processing Record 41 of Set 12 | touros
# Processing Record 42 of Set 12 | kirksville
# Processing Record 43 of Set 12 | golden
# Processing Record 44 of Set 12 | kapoeta
# Processing Record 45 of Set 12 | dzilam gonzalez
# Processing Record 46 of Set 12 | shirokiy
# Processing Record 47 of Set 12 | sambava
# Processing Record 48 of Set 12 | kuche
# City not found. Skipping...
# Processing Record 49 of Set 12 | venustiano carranza
# Processing Record 50 of Set 12 | pakxan
# Processing Record 1 of Set 13 | souris
# Processing Record 2 of Set 13 | huarmey
# Processing Record 3 of Set 13 | santona
# Processing Record 4 of Set 13 | west memphis
# Processing Record 5 of Set 13 | kyren
# Processing Record 6 of Set 13 | mersing
# Processing Record 7 of Set 13 | aloleng
# Processing Record 8 of Set 13 | baiyin
# Processing Record 9 of Set 13 | viedma
# Processing Record 10 of Set 13 | linchuan
# City not found. Skipping...
# Processing Record 11 of Set 13 | kismayo
# Processing Record 12 of Set 13 | esperance
# Processing Record 13 of Set 13 | port-de-bouc
# Processing Record 14 of Set 13 | edd
# Processing Record 15 of Set 13 | lashio
# Processing Record 16 of Set 13 | pietersburg
# Processing Record 17 of Set 13 | nivala
# Processing Record 18 of Set 13 | katherine
# Processing Record 19 of Set 13 | tsihombe
# City not found. Skipping...
# Processing Record 20 of Set 13 | san antero
# Processing Record 21 of Set 13 | kalmunai
# Processing Record 22 of Set 13 | skogn
# Processing Record 23 of Set 13 | rudbar
# Processing Record 24 of Set 13 | aswan
# Processing Record 25 of Set 13 | sturgeon falls
# Processing Record 26 of Set 13 | bilma
# Processing Record 27 of Set 13 | dillon
# Processing Record 28 of Set 13 | krasnoselkup
# Processing Record 29 of Set 13 | aksha
# Processing Record 30 of Set 13 | dunedin
# Processing Record 31 of Set 13 | norsup
# Processing Record 32 of Set 13 | rolim de moura
# City not found. Skipping...
# Processing Record 33 of Set 13 | iquique
# Processing Record 34 of Set 13 | nsoko
# Processing Record 35 of Set 13 | beringovskiy
# Processing Record 36 of Set 13 | vicuna
# Processing Record 37 of Set 13 | dicabisagan
# Processing Record 38 of Set 13 | hailin
# Processing Record 39 of Set 13 | sokolo
# Processing Record 40 of Set 13 | hurricane
# Processing Record 41 of Set 13 | porosozero
# Processing Record 42 of Set 13 | najran
# Processing Record 43 of Set 13 | ust-kalmanka
# Processing Record 44 of Set 13 | agropoli
# Processing Record 45 of Set 13 | broken hill
# Processing Record 46 of Set 13 | pedernales
# Processing Record 47 of Set 13 | sechura
# Processing Record 48 of Set 13 | oakdale
# Processing Record 49 of Set 13 | korla
# Processing Record 50 of Set 13 | chardara
# Processing Record 1 of Set 14 | den helder
# Processing Record 2 of Set 14 | jaguaruna
# Processing Record 3 of Set 14 | tynda
# Processing Record 4 of Set 14 | utiroa
# City not found. Skipping...
# Processing Record 5 of Set 14 | broome
# Processing Record 6 of Set 14 | seymchan
# Processing Record 7 of Set 14 | moron
# Processing Record 8 of Set 14 | saleaula
# City not found. Skipping...
# Processing Record 9 of Set 14 | iacu
# Processing Record 10 of Set 14 | san juan
# Processing Record 11 of Set 14 | tecolutilla
# Processing Record 12 of Set 14 | tautira
# Processing Record 13 of Set 14 | anda
# Processing Record 14 of Set 14 | kristiinankaupunki
# Processing Record 15 of Set 14 | tunduru
# City not found. Skipping...
# Processing Record 16 of Set 14 | tulagi
# Processing Record 17 of Set 14 | ouesso
# Processing Record 18 of Set 14 | omboue
# Processing Record 19 of Set 14 | banff
# Processing Record 20 of Set 14 | fare
# Processing Record 21 of Set 14 | caravelas
# Processing Record 22 of Set 14 | zhigansk
# Processing Record 23 of Set 14 | pangai
# Processing Record 24 of Set 14 | aviles
# Processing Record 25 of Set 14 | itaituba
# Processing Record 26 of Set 14 | san vicente
# Processing Record 27 of Set 14 | mae hong son
# Processing Record 28 of Set 14 | safford
# Processing Record 29 of Set 14 | dickson
# Processing Record 30 of Set 14 | requena
# Processing Record 31 of Set 14 | beruwala
# Processing Record 32 of Set 14 | namatanai
# Processing Record 33 of Set 14 | musoma
# Processing Record 34 of Set 14 | kac
# City not found. Skipping...
# Processing Record 35 of Set 14 | rengo
# Processing Record 36 of Set 14 | antsohihy
# Processing Record 37 of Set 14 | general roca
# Processing Record 38 of Set 14 | menongue
# Processing Record 39 of Set 14 | alyangula
# Processing Record 40 of Set 14 | westerland
# Processing Record 41 of Set 14 | buta
# Processing Record 42 of Set 14 | tignere
# Processing Record 43 of Set 14 | axim
# Processing Record 44 of Set 14 | mrirt
# City not found. Skipping...
# Processing Record 45 of Set 14 | kargasok
# Processing Record 46 of Set 14 | cao bang
# Processing Record 47 of Set 14 | sladkovo
# Processing Record 48 of Set 14 | arlit
# Processing Record 49 of Set 14 | dimbokro
# Processing Record 50 of Set 14 | baft
# Processing Record 1 of Set 15 | mount isa
# Processing Record 2 of Set 15 | poum
# Processing Record 3 of Set 15 | barcelona
# Processing Record 4 of Set 15 | itoman
# Processing Record 5 of Set 15 | tommot
# Processing Record 6 of Set 15 | sao filipe
# Processing Record 7 of Set 15 | cabo rojo
# Processing Record 8 of Set 15 | stornoway
# Processing Record 9 of Set 15 | sorland
# Processing Record 10 of Set 15 | kita
# Processing Record 11 of Set 15 | erenhot
# Processing Record 12 of Set 15 | indramayu
# Processing Record 13 of Set 15 | dholka
# Processing Record 14 of Set 15 | teya
# Processing Record 15 of Set 15 | luanda
# Processing Record 16 of Set 15 | puga
# Processing Record 17 of Set 15 | mao
# Processing Record 18 of Set 15 | aksum
# Processing Record 19 of Set 15 | leh
# Processing Record 20 of Set 15 | manaus
# Processing Record 21 of Set 15 | dujuma
# City not found. Skipping...
# Processing Record 22 of Set 15 | shugurovo
# Processing Record 23 of Set 15 | canon city
# Processing Record 24 of Set 15 | uige
# Processing Record 25 of Set 15 | riverton
# Processing Record 26 of Set 15 | soc trang
# Processing Record 27 of Set 15 | minab
# Processing Record 28 of Set 15 | katobu
# Processing Record 29 of Set 15 | lac du bonnet
# Processing Record 30 of Set 15 | charlestown
# Processing Record 31 of Set 15 | kaseda
# Processing Record 32 of Set 15 | pyshma
# Processing Record 33 of Set 15 | mengcheng
# Processing Record 34 of Set 15 | bengkulu
# Processing Record 35 of Set 15 | paramonga
# Processing Record 36 of Set 15 | quatre cocos
# Processing Record 37 of Set 15 | saint-paul
# Processing Record 38 of Set 15 | caborca
# Processing Record 39 of Set 15 | aguas vermelhas
# Processing Record 40 of Set 15 | obo
# Processing Record 41 of Set 15 | karratha
# Processing Record 42 of Set 15 | bubaque
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_weather = requests.get(city_url).json()

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed
# 0     Victoria  22.2855  114.1577     69.85        55           5        6.60
# 1  Tuktoyaktuk  69.4541 -133.0374    -11.20        77          90       17.27
# 2      Ushuaia -54.8000  -68.3000     40.66        81          75       24.16
# 3      Lourdes  43.1000   -0.0500     34.72       100          90        8.05
# 4         Lebu -37.6167  -73.6500     53.20        79           7       18.95

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
